# %% [markdown]
# # Prediction of housing prices using linear regression

# %%
import pandas as pd
from sklearn.preprocessing import OrdinalEncoder
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ## Reading training set of data

# %%
training_set_path = '../dataset/train.csv'
training_set = pd.read_csv(training_set_path)
training_set.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# min       1.000000  1872.000000   1950.000000     0.000000     0.000000  ...
# 25%       5.000000  1954.000000   1967.000000     0.000000     0.000000  ...
# 50%       5.000000  1973.000000   1994.000000     0.000000   383.500000  ...
# 75%       6.000000  2000.000000   2004.000000   166.000000   712.250000  ...
# max       9.000000  2010.000000   2010.000000  1600.000000  5644.000000  ...
#
#         WoodDeckSF  OpenPorchSF  EnclosedPorch    3SsnPorch  ScreenPorch  \
# count  1460.000000  1460.000000    1460.000000  1460.000000  1460.000000
# mean     94.244521    46.660274      21.954110     3.409589    15.060959
# std     125.338794    66.256028      61.119149    29.317331    55.757415
# min       0.000000     0.000000       0.000000     0.000000     0.000000
# 25%       0.000000     0.000000       0.000000     0.000000     0.000000
# 50%       0.000000    25.000000       0.000000     0.000000     0.000000
# 75%     168.000000    68.000000       0.000000     0.000000     0.000000
# max     857.000000   547.000000     552.000000   508.000000   480.000000
#
#           PoolArea       MiscVal       MoSold       YrSold      SalePrice
# count  1460.000000   1460.000000  1460.000000  1460.000000    1460.000000
# mean      2.758904     43.489041     6.321918  2007.815753  180921.195890
# std      40.177307    496.123024     2.703626     1.328095   79442.502883
# min       0.000000      0.000000     1.000000  2006.000000   34900.000000
# 25%       0.000000      0.000000     5.000000  2007.000000  129975.000000
# 50%       0.000000      0.000000     6.000000  2008.000000  163000.000000
# 75%       0.000000      0.000000     8.000000  2009.000000  214000.000000
# max     738.000000  15500.000000    12.000000  2010.000000  755000.000000
#
# [8 rows x 38 columns]

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Cleaning

# %%
# Dropping problematic column(s)
training_set.drop(labels=['Alley'], axis=1, inplace=True)

# %% [markdown]
# ### Encoding Categorical Fetures

# %%
# !!! Nominal features are treated as Orinal !!!
encoder = OrdinalEncoder()

# Finding categorical columns and features
categorical_columns = [column for column in training_set if isinstance(training_set[column][0], str)]
categorical_features = training_set[categorical_columns]

# Encoding categorical features into numerical value
encoder.fit(categorical_features) 
training_set.loc[:, categorical_columns] = encoder.transform(categorical_features)
training_set
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 0        1          60      3.0         65.0     8450    1.0      3.0
# 1        2          20      3.0         80.0     9600    1.0      3.0
# 2        3          60      3.0         68.0    11250    1.0      0.0
# 3        4          70      3.0         60.0     9550    1.0      0.0
# 4        5          60      3.0         84.0    14260    1.0      0.0
# ...    ...         ...      ...          ...      ...    ...      ...
# 1455  1456          60      3.0         62.0     7917    1.0      3.0
# 1456  1457          20      3.0         85.0    13175    1.0      3.0
# 1457  1458          70      3.0         66.0     9042    1.0      3.0
# 1458  1459          20      3.0         68.0     9717    1.0      3.0
# 1459  1460          20      3.0         75.0     9937    1.0      3.0
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature  \
# 0            3.0       0.0       4.0  ...        0    NaN    NaN         NaN
# 1            3.0       0.0       2.0  ...        0    NaN    NaN         NaN
# 2            3.0       0.0       4.0  ...        0    NaN    NaN         NaN
# 3            3.0       0.0       0.0  ...        0    NaN    NaN         NaN
# 4            3.0       0.0       2.0  ...        0    NaN    NaN         NaN
# ...          ...       ...       ...  ...      ...    ...    ...         ...
# 1455         3.0       0.0       4.0  ...        0    NaN    NaN         NaN
# 1456         3.0       0.0       4.0  ...        0    NaN  MnPrv         NaN
# 1457         3.0       0.0       4.0  ...        0    NaN  GdPrv        Shed
# 1458         3.0       0.0       4.0  ...        0    NaN    NaN         NaN
# 1459         3.0       0.0       4.0  ...        0    NaN    NaN         NaN
#
#      MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# 0          0      2    2008       8.0            4.0     208500
# 1          0      5    2007       8.0            4.0     181500
# 2          0      9    2008       8.0            4.0     223500
# 3          0      2    2006       8.0            0.0     140000
# 4          0     12    2008       8.0            4.0     250000
# ...      ...    ...     ...       ...            ...        ...
# 1455       0      8    2007       8.0            4.0     175000
# 1456       0      2    2010       8.0            4.0     210000
# 1457    2500      5    2010       8.0            4.0     266500
# 1458       0      4    2010       8.0            4.0     142125
# 1459       0      6    2008       8.0            4.0     147500
#
# [1460 rows x 80 columns]

# %% [markdown]
# ## Building a Linear Regression Model

# %% [markdown]
# ### Selecting Features

# %%
# Cell above shown columns[0]=='id' and columns[-1]=='SalePrice'
feature_columns = training_set.columns[1:-1]  # from [1] to [-2]
x = training_set[feature_columns]
x
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0             60      3.0         65.0     8450    1.0      3.0         3.0
# 1             20      3.0         80.0     9600    1.0      3.0         3.0
# 2             60      3.0         68.0    11250    1.0      0.0         3.0
# 3             70      3.0         60.0     9550    1.0      0.0         3.0
# 4             60      3.0         84.0    14260    1.0      0.0         3.0
# ...          ...      ...          ...      ...    ...      ...         ...
# 1455          60      3.0         62.0     7917    1.0      3.0         3.0
# 1456          20      3.0         85.0    13175    1.0      3.0         3.0
# 1457          70      3.0         66.0     9042    1.0      3.0         3.0
# 1458          20      3.0         68.0     9717    1.0      3.0         3.0
# 1459          20      3.0         75.0     9937    1.0      3.0         3.0
#
#      Utilities LotConfig LandSlope  ... ScreenPorch PoolArea PoolQC  Fence  \
# 0          0.0       4.0       0.0  ...           0        0    NaN    NaN
# 1          0.0       2.0       0.0  ...           0        0    NaN    NaN
# 2          0.0       4.0       0.0  ...           0        0    NaN    NaN
# 3          0.0       0.0       0.0  ...           0        0    NaN    NaN
# 4          0.0       2.0       0.0  ...           0        0    NaN    NaN
# ...        ...       ...       ...  ...         ...      ...    ...    ...
# 1455       0.0       4.0       0.0  ...           0        0    NaN    NaN
# 1456       0.0       4.0       0.0  ...           0        0    NaN  MnPrv
# 1457       0.0       4.0       0.0  ...           0        0    NaN  GdPrv
# 1458       0.0       4.0       0.0  ...           0        0    NaN    NaN
# 1459       0.0       4.0       0.0  ...           0        0    NaN    NaN
#
#      MiscFeature  MiscVal  MoSold  YrSold  SaleType SaleCondition
# 0            NaN        0       2    2008       8.0           4.0
# 1            NaN        0       5    2007       8.0           4.0
# 2            NaN        0       9    2008       8.0           4.0
# 3            NaN        0       2    2006       8.0           0.0
# 4            NaN        0      12    2008       8.0           4.0
# ...          ...      ...     ...     ...       ...           ...
# 1455         NaN        0       8    2007       8.0           4.0
# 1456         NaN        0       2    2010       8.0           4.0
# 1457        Shed     2500       5    2010       8.0           4.0
# 1458         NaN        0       4    2010       8.0           4.0
# 1459         NaN        0       6    2008       8.0           4.0
#
# [1460 rows x 78 columns]

# %% [markdown]
# ### Selecting Prediction Target

# %%
y = training_set.SalePrice

# %% [markdown]
# ### Fitting a linear model

# %%
model = LinearRegression().fit(x, y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3364\4194991417.py in ?()
# ----> 1 model = LinearRegression().fit(x, y)
#
# c:\Users\User\Documents\SideProject\house-price-regression\.venv\Lib\site-packages\sklearn\base.py in ?(estimator, *args, **kwargs)
#    1385                 skip_parameter_validation=(
#    1386                     prefer_skip_nested_validation or global_skip_validation
#    1387                 )
#    1388             ):
# -> 1389                 return fit_method(estimator, *args, **kwargs)
#
# c:\Users\User\Documents\SideProject\house-price-regression\.venv\Lib\site-packages\sklearn\linear_model\_base.py in ?(self, X, y, sample_weight)
#     597         n_jobs_ = self.n_jobs
#     598
#     599         accept_sparse = False if self.positive else ["csr", "csc", "coo"]
#     600
# --> 601         X, y = validate_data(
#     602             self,
#     603             X,
#     604             y,
#
# c:\Users\User\Documents\SideProject\house-price-regression\.venv\Lib\site-packages\sklearn\utils\validation.py in ?(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    2957             if "estimator" not in check_y_params:
#    2958                 check_y_params = {**default_check_params, **check_y_params}
#    2959             y = check_array(y, input_name="y", **check_y_params)
#    2960         else:
# -> 2961             X, y = check_X_y(X, y, **check_params)
#    2962         out = X, y
#    2963
#    2964     if not no_val_X and check_params.get("ensure_2d", True):
#
# c:\Users\User\Documents\SideProject\house-price-regression\.venv\Lib\site-packages\sklearn\utils\validation.py in ?(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1366         )
#    1367
#    1368     ensure_all_finite = _deprecate_force_all_finite(force_all_finite, ensure_all_finite)
#    1369
# -> 1370     X = check_array(
#    1371         X,
#    1372         accept_sparse=accept_sparse,
#    1373         accept_large_sparse=accept_large_sparse,
#
# c:\Users\User\Documents\SideProject\house-price-regression\.venv\Lib\site-packages\sklearn\utils\validation.py in ?(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1052                         )
#    1053                     array = xp.astype(array, dtype, copy=False)
#    1054                 else:
#    1055                     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
# -> 1056             except ComplexWarning as complex_warning:
#    1057                 raise ValueError(
#    1058                     "Complex data not supported\n{}\n".format(array)
#    1059                 ) from complex_warning
#
# c:\Users\User\Documents\SideProject\house-price-regression\.venv\Lib\site-packages\sklearn\utils\_array_api.py in ?(array, dtype, order, copy, xp, device)
#     828         # Use NumPy API to support order
#     829         if copy is True:
#     830             array = numpy.array(array, order=order, dtype=dtype)
#     831         else:
# --> 832             array = numpy.asarray(array, order=order, dtype=dtype)
#     833
#     834         # At this point array is a NumPy ndarray. We convert it to an array
#     835         # container that is consistent with the input's namespace.
#
# c:\Users\User\Documents\SideProject\house-price-regression\.venv\Lib\site-packages\pandas\core\generic.py in ?(self, dtype, copy)
#    2149     def __array__(
#    2150         self, dtype: npt.DTypeLike | None = None, copy: bool_t | None = None
#    2151     ) -> np.ndarray:
#    2152         values = self._values
# -> 2153         arr = np.asarray(values, dtype=dtype)
#    2154         if (
#    2155             astype_is_view(values.dtype, arr.dtype)
#    2156             and using_copy_on_write()
#
# ValueError: could not convert string to float: 'TA'
