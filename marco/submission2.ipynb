# %% [markdown]
# # House Prices Prediction

# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, ExtraTreesRegressor
from sklearn.metrics import mean_absolute_error
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import OrdinalEncoder
from sklearn.preprocessing import StandardScaler


from pycaret.regression import setup, compare_models
from sklearn.model_selection import KFold, cross_val_score
import lightgbm as lgb

from sklearn.linear_model import BayesianRidge, HuberRegressor, Ridge, OrthogonalMatchingPursuit

# %% [markdown]
# ### Read Data

# %%
training_set_path = '../dataset/train.csv'
train0 = pd.read_csv(training_set_path)

testing_set_path = '../dataset/test.csv'
test0 = pd.read_csv(testing_set_path)

# %% [markdown]
# ## Cleaning

# %% [markdown]
# ### Drop Outlier

# %%
train1 = train0[train0.GrLivArea < 4500]
train1.dropna(axis=0, subset=['MasVnrArea', 'Electrical'], inplace=True)
train1.reset_index(drop=True, inplace=True)

# %% [markdown]
# ### Concrat train and test set

# %%
y = train1['SalePrice']
test_ids = test0['Id']

train1.drop(['Id', 'SalePrice'], axis=1, inplace=True)
test0.drop(['Id'], axis=1, inplace=True)

data1 = pd.concat([train1, test0], axis=0).reset_index(drop=True)
data1
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0             60       RL         65.0     8450   Pave   NaN      Reg
# 1             20       RL         80.0     9600   Pave   NaN      Reg
# 2             60       RL         68.0    11250   Pave   NaN      IR1
# 3             70       RL         60.0     9550   Pave   NaN      IR1
# 4             60       RL         84.0    14260   Pave   NaN      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 2903         160       RM         21.0     1936   Pave   NaN      Reg
# 2904         160       RM         21.0     1894   Pave   NaN      Reg
# 2905          20       RL        160.0    20000   Pave   NaN      Reg
# 2906          85       RL         62.0    10441   Pave   NaN      Reg
# 2907          60       RL         74.0     9627   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig  ... ScreenPorch PoolArea PoolQC  Fence  \
# 0            Lvl    AllPub    Inside  ...           0        0    NaN    NaN
# 1            Lvl    AllPub       FR2  ...           0        0    NaN    NaN
# 2            Lvl    AllPub    Inside  ...           0        0    NaN    NaN
# 3            Lvl    AllPub    Corner  ...           0        0    NaN    NaN
# 4            Lvl    AllPub       FR2  ...           0        0    NaN    NaN
# ...          ...       ...       ...  ...         ...      ...    ...    ...
# 2903         Lvl    AllPub    Inside  ...           0        0    NaN    NaN
# 2904         Lvl    AllPub    Inside  ...           0        0    NaN    NaN
# 2905         Lvl    AllPub    Inside  ...           0        0    NaN    NaN
# 2906         Lvl    AllPub    Inside  ...           0        0    NaN  MnPrv
# 2907         Lvl    AllPub    Inside  ...           0        0    NaN    NaN
#
#      MiscFeature MiscVal  MoSold  YrSold  SaleType  SaleCondition
# 0            NaN       0       2    2008        WD         Normal
# 1            NaN       0       5    2007        WD         Normal
# 2            NaN       0       9    2008        WD         Normal
# 3            NaN       0       2    2006        WD        Abnorml
# 4            NaN       0      12    2008        WD         Normal
# ...          ...     ...     ...     ...       ...            ...
# 2903         NaN       0       6    2006        WD         Normal
# 2904         NaN       0       4    2006        WD        Abnorml
# 2905         NaN       0       9    2006        WD        Abnorml
# 2906        Shed     700       7    2006        WD         Normal
# 2907         NaN       0      11    2006        WD         Normal
#
# [2908 rows x 79 columns]

# %% [markdown]
# ### Set data type as str

# %%
data2 = data1.copy()

# %%
data2['MSSubClass'] = data2['MSSubClass'].astype(str)

# %% [markdown]
# ### Fill Missing Value (Catagorical)

# %%
#For these columns, missing value means the feature is not available. So 'None' is filled, which is easier for future features engineering.
for column in [
    'Alley',
    'BsmtQual',
    'BsmtCond',
    'BsmtExposure',
    'BsmtFinType1',
    'BsmtFinType2',
    'FireplaceQu',
    'GarageType',
    'GarageFinish',
    'GarageQual',
    'GarageCond',
    'PoolQC',
    'Fence',
    'MiscFeature'
]:
    data2[column] = data2[column].fillna("None")

#In the data description document, these columns are not supposed to contain missing value.
#Therefore, we are filling the mode of the column as the missing value
for column in [
    'MSZoning',
    'Utilities',
    'Exterior1st',
    'Exterior2nd',
    'MasVnrType',
    'Electrical',
    'KitchenQual',
    'Functional',
    'SaleType'
]:
    data2[column] = data2[column].fillna(data2[column].mode()[0])

# %% [markdown]
# ### Fill Missing Value (Numeric)

# %%
for column in [
    'LotFrontage',
    'MasVnrArea',
    'BsmtFinSF1',
    'BsmtFinSF2',
    'BsmtUnfSF',
    'TotalBsmtSF',
    'BsmtFullBath',
    'BsmtHalfBath',
    'GarageYrBlt',
    'GarageCars',
    'GarageArea'
]:
    data2[column] = data2[column].fillna(0)

# %% [markdown]
# ## Features Engineering

# %% [markdown]
# ### Binary Transformation

# %%
data3 = data2.copy()

# %%
#Convert the columns 'CentralAir' from (Y/N) to (1/0)
data3['CentralAir'] = data3['CentralAir'].replace({'Y': 1, 'N': 0})

#Convert the data in the column 'Street' to binary, where 'Pave' to 1 and 'Grvl' to 0.
data3['Street'] = data3['Street'].replace({'Pave': 1, 'Grvl': 0})

#Convert the data in the column 'Alley' to binary.
#The way of doing it is to group 'Pave' and 'Grvl'
#If the property has an alley access, then 1; 
#Otherwise 0.
data3['Alley'] = data3['Alley'].replace({'Pave': 1, 'Grvl': 1, 'None': 0})

#Convert the data in the column 'LotShape' to binary, where 'Reg' to 1 and grouping 'IR1', 'IR2' and 'IR3' to 0.
#If the shape of the property is regular, then 1;
#Otherwise 0.
data3['LotShape'] = data3['LotShape'].replace({'Reg': 1, 'IR1': 0, 'IR2': 0, 'IR3': 0})

#Convert the data in the column 'LandContour' to binary, where 'Lvl' to 1 and grouping 'Bnk', 'HLS' and 'Low' to 0.
#If the property is near flat/level, then 1;
#Otherwise 0.
data3['LandContour'] = data3['LandContour'].replace({'Lvl': 1, 'Bnk': 0, 'HLS': 0, 'Low': 0})

#Convert the data in the column 'Utilities' to binary, where 'AllPub' to 1 and grouping 'NoSewr', 'NoSeWa' and 'ELO' to 0.
#If all type of utilities is available, then 1;
#Otherwise 0.
data3['Utilities'] = data3['Utilities'].replace({'AllPub': 1, 'NoSewr': 0, 'NoSeWa': 0, 'ELO': 0})

# %% [markdown]
# ### Ordinal Encoding

# %%
data4 = data3.copy()

# %%
#Define the desired order for each categorical feature
LandSlope_order = ['Sev', 'Mod', 'Gtl']
ExterQual_order = ['Po', 'Fa', 'TA', 'Gd', 'Ex']
ExterCond_order = ['Po', 'Fa', 'TA', 'Gd', 'Ex']
BsmtQual_order = ['None', 'Po', 'Fa', 'TA', 'Gd', 'Ex']
BsmtCond_order = ['None', 'Po', 'Fa', 'TA', 'Gd', 'Ex']
BsmtExposure_order = ['None', 'No', 'Mn', 'Av', 'Gd']
BsmtFinType1_order = ['None', 'Unf', 'LwQ', 'Rec', 'BLQ', 'ALQ', 'GLQ']
BsmtFinType2_order = ['None', 'Unf', 'LwQ', 'Rec', 'BLQ', 'ALQ', 'GLQ']
HeatingQC_order = ['Po', 'Fa', 'TA', 'Gd', 'Ex']
KitchenQual_order = ['Po', 'Fa', 'TA', 'Gd', 'Ex']
Functional_order = ['Sal', 'Sev', 'Maj2', 'Maj1', 'Mod', 'Min2', 'Min1', 'Typ']
FireplaceQu_order = ['None', 'Po', 'Fa', 'TA', 'Gd', 'Ex']
GarageFinish_order = ['None', 'Unf', 'RFn', 'Fin']
GarageQual_order = ['None', 'Po', 'Fa', 'TA', 'Gd', 'Ex']
GarageCond_order = ['None', 'Po', 'Fa', 'TA', 'Gd', 'Ex']
PavedDrive_order = ['N', 'P', 'Y']
PoolQC_order = ['None', 'Fa', 'TA', 'Gd', 'Ex']
Fence_order = ['None', 'MnWw', 'GdWo', 'MnPrv', 'GdPrv']

# List of columns to transform
columns_to_transform_OE = [
    'LandSlope', 'ExterQual', 'ExterCond', 'BsmtQual', 'BsmtCond',
    'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'HeatingQC',
    'KitchenQual', 'Functional', 'FireplaceQu', 'GarageFinish',
    'GarageQual', 'GarageCond', 'PavedDrive', 'PoolQC', 'Fence'
]

# Convert specified columns to strings
data4[columns_to_transform_OE] = data4[columns_to_transform_OE].astype(str)

# Create an instance of OrdinalEncoder with specified categories
ordinal_encoder = OrdinalEncoder(categories=[
    LandSlope_order,
    ExterQual_order,
    ExterCond_order,
    BsmtQual_order,
    BsmtCond_order,
    BsmtExposure_order,
    BsmtFinType1_order,
    BsmtFinType2_order,
    HeatingQC_order,
    KitchenQual_order,
    Functional_order,
    FireplaceQu_order,
    GarageFinish_order,
    GarageQual_order,
    GarageCond_order,
    PavedDrive_order,
    PoolQC_order,
    Fence_order
])

# Apply the encoder to the specified columns
encoded_columns_OE = ordinal_encoder.fit_transform(data4[columns_to_transform_OE])

# Create a new DataFrame with encoded values
OE_df = pd.DataFrame(encoded_columns_OE, columns=columns_to_transform_OE)

clean_set_dropped = data4.drop(columns=columns_to_transform_OE)

data4 = pd.concat([clean_set_dropped, OE_df], axis=1)

# %% [markdown]
# ### Catagorical Variables

# %%
data5 = data4.copy()

# %%
data5 = pd.get_dummies(data5)

# %% [markdown]
# ### Date Columns

# %% [markdown]
# ### Cyclical Encoding (MoSold)

# %%
data6 = data5.copy()

# %%
data6['MoSold'] = -np.cos((2 * np.pi / 12) * data6['MoSold'])

# %% [markdown]
# ### Year Difference (YrSold)

# %%
data6['YrSold'] = 2010 - data6['YrSold']

# %%
data7 = data6.copy()

# %% [markdown]
# ## Split the data

# %%
train_split = data7.loc[:train1.index.max(), :].copy()
test_split = data7.loc[train1.index.max() + 1:, :].reset_index(drop=True).copy()

# %% [markdown]
# ## Scaling

# %% [markdown]
# Scaling after the split to prevent data leakage

# %%
scaler = StandardScaler()
scaler.fit(train_split)

train_final = pd.DataFrame(scaler.transform(train_split), index = train_split.index, columns = train_split.columns)
test_final = pd.DataFrame(scaler.transform(test_split), index = test_split.index, columns = test_split.columns)

# %% [markdown]
# ## Y Transformation

# %%
log_y = np.log(y)

# %% [markdown]
# ## Model Selection

# %%
_ = setup(data = pd.concat([train_final, log_y], axis = 1), target = 'SalePrice')
# Out:
# <style type="text/css">
# #T_6e8bb_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_6e8bb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6e8bb_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_6e8bb_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6e8bb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6e8bb_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_6e8bb_row0_col1" class="data row0 col1" >2109</td>
#     </tr>
#     <tr>
#       <th id="T_6e8bb_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6e8bb_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_6e8bb_row1_col1" class="data row1 col1" >SalePrice</td>
#     </tr>
#     <tr>
#       <th id="T_6e8bb_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6e8bb_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_6e8bb_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_6e8bb_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_6e8bb_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_6e8bb_row3_col1" class="data row3 col1" >(1449, 232)</td>
#     </tr>
#     <tr>
#       <th id="T_6e8bb_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_6e8bb_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_6e8bb_row4_col1" class="data row4 col1" >(1449, 232)</td>
#     </tr>
#     <tr>
#       <th id="T_6e8bb_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_6e8bb_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_6e8bb_row5_col1" class="data row5 col1" >(1014, 232)</td>
#     </tr>
#     <tr>
#       <th id="T_6e8bb_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_6e8bb_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_6e8bb_row6_col1" class="data row6 col1" >(435, 232)</td>
#     </tr>
#     <tr>
#       <th id="T_6e8bb_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_6e8bb_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_6e8bb_row7_col1" class="data row7 col1" >231</td>
#     </tr>
#     <tr>
#       <th id="T_6e8bb_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_6e8bb_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_6e8bb_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_6e8bb_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_6e8bb_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_6e8bb_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_6e8bb_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_6e8bb_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_6e8bb_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_6e8bb_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_6e8bb_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_6e8bb_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_6e8bb_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_6e8bb_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_6e8bb_row12_col1" class="data row12 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_6e8bb_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_6e8bb_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_6e8bb_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_6e8bb_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_6e8bb_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_6e8bb_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_6e8bb_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_6e8bb_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_6e8bb_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_6e8bb_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_6e8bb_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_6e8bb_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_6e8bb_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_6e8bb_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_6e8bb_row17_col1" class="data row17 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_6e8bb_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_6e8bb_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_6e8bb_row18_col1" class="data row18 col1" >30d7</td>
#     </tr>
#   </tbody>
# </table>

# %%
compare_models()
# Out:
# <style type="text/css">
# #T_0c2be th {
#   text-align: left;
# }
# #T_0c2be_row0_col0, #T_0c2be_row1_col0, #T_0c2be_row1_col1, #T_0c2be_row1_col2, #T_0c2be_row1_col3, #T_0c2be_row1_col4, #T_0c2be_row1_col5, #T_0c2be_row1_col6, #T_0c2be_row2_col0, #T_0c2be_row2_col1, #T_0c2be_row2_col2, #T_0c2be_row2_col3, #T_0c2be_row2_col4, #T_0c2be_row2_col5, #T_0c2be_row2_col6, #T_0c2be_row3_col0, #T_0c2be_row3_col1, #T_0c2be_row3_col2, #T_0c2be_row3_col3, #T_0c2be_row3_col4, #T_0c2be_row3_col5, #T_0c2be_row3_col6, #T_0c2be_row4_col0, #T_0c2be_row4_col1, #T_0c2be_row4_col2, #T_0c2be_row4_col3, #T_0c2be_row4_col4, #T_0c2be_row4_col5, #T_0c2be_row4_col6, #T_0c2be_row5_col0, #T_0c2be_row5_col1, #T_0c2be_row5_col2, #T_0c2be_row5_col3, #T_0c2be_row5_col4, #T_0c2be_row5_col5, #T_0c2be_row5_col6, #T_0c2be_row6_col0, #T_0c2be_row6_col1, #T_0c2be_row6_col2, #T_0c2be_row6_col3, #T_0c2be_row6_col4, #T_0c2be_row6_col5, #T_0c2be_row6_col6, #T_0c2be_row7_col0, #T_0c2be_row7_col1, #T_0c2be_row7_col2, #T_0c2be_row7_col3, #T_0c2be_row7_col4, #T_0c2be_row7_col5, #T_0c2be_row7_col6, #T_0c2be_row8_col0, #T_0c2be_row8_col1, #T_0c2be_row8_col2, #T_0c2be_row8_col3, #T_0c2be_row8_col4, #T_0c2be_row8_col5, #T_0c2be_row8_col6, #T_0c2be_row9_col0, #T_0c2be_row9_col1, #T_0c2be_row9_col2, #T_0c2be_row9_col3, #T_0c2be_row9_col4, #T_0c2be_row9_col5, #T_0c2be_row9_col6, #T_0c2be_row10_col0, #T_0c2be_row10_col1, #T_0c2be_row10_col2, #T_0c2be_row10_col3, #T_0c2be_row10_col4, #T_0c2be_row10_col5, #T_0c2be_row10_col6, #T_0c2be_row11_col0, #T_0c2be_row11_col1, #T_0c2be_row11_col2, #T_0c2be_row11_col3, #T_0c2be_row11_col4, #T_0c2be_row11_col5, #T_0c2be_row11_col6, #T_0c2be_row12_col0, #T_0c2be_row12_col1, #T_0c2be_row12_col2, #T_0c2be_row12_col3, #T_0c2be_row12_col4, #T_0c2be_row12_col5, #T_0c2be_row12_col6, #T_0c2be_row13_col0, #T_0c2be_row13_col1, #T_0c2be_row13_col2, #T_0c2be_row13_col3, #T_0c2be_row13_col4, #T_0c2be_row13_col5, #T_0c2be_row13_col6, #T_0c2be_row14_col0, #T_0c2be_row14_col1, #T_0c2be_row14_col2, #T_0c2be_row14_col3, #T_0c2be_row14_col4, #T_0c2be_row14_col5, #T_0c2be_row14_col6, #T_0c2be_row15_col0, #T_0c2be_row15_col1, #T_0c2be_row15_col2, #T_0c2be_row15_col3, #T_0c2be_row15_col4, #T_0c2be_row15_col5, #T_0c2be_row15_col6, #T_0c2be_row16_col0, #T_0c2be_row16_col1, #T_0c2be_row16_col2, #T_0c2be_row16_col3, #T_0c2be_row16_col4, #T_0c2be_row16_col5, #T_0c2be_row16_col6, #T_0c2be_row17_col0, #T_0c2be_row17_col1, #T_0c2be_row17_col2, #T_0c2be_row17_col3, #T_0c2be_row17_col4, #T_0c2be_row17_col5, #T_0c2be_row17_col6 {
#   text-align: left;
# }
# #T_0c2be_row0_col1, #T_0c2be_row0_col2, #T_0c2be_row0_col3, #T_0c2be_row0_col4, #T_0c2be_row0_col5, #T_0c2be_row0_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_0c2be_row0_col7, #T_0c2be_row1_col7, #T_0c2be_row2_col7, #T_0c2be_row3_col7, #T_0c2be_row4_col7, #T_0c2be_row5_col7, #T_0c2be_row6_col7, #T_0c2be_row7_col7, #T_0c2be_row8_col7, #T_0c2be_row9_col7, #T_0c2be_row10_col7, #T_0c2be_row11_col7, #T_0c2be_row12_col7, #T_0c2be_row14_col7, #T_0c2be_row15_col7, #T_0c2be_row16_col7, #T_0c2be_row17_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_0c2be_row13_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_0c2be">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0c2be_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_0c2be_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_0c2be_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_0c2be_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_0c2be_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_0c2be_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_0c2be_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_0c2be_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0c2be_level0_row0" class="row_heading level0 row0" >br</th>
#       <td id="T_0c2be_row0_col0" class="data row0 col0" >Bayesian Ridge</td>
#       <td id="T_0c2be_row0_col1" class="data row0 col1" >0.0833</td>
#       <td id="T_0c2be_row0_col2" class="data row0 col2" >0.0141</td>
#       <td id="T_0c2be_row0_col3" class="data row0 col3" >0.1182</td>
#       <td id="T_0c2be_row0_col4" class="data row0 col4" >0.9133</td>
#       <td id="T_0c2be_row0_col5" class="data row0 col5" >0.0092</td>
#       <td id="T_0c2be_row0_col6" class="data row0 col6" >0.0070</td>
#       <td id="T_0c2be_row0_col7" class="data row0 col7" >0.0140</td>
#     </tr>
#     <tr>
#       <th id="T_0c2be_level0_row1" class="row_heading level0 row1" >omp</th>
#       <td id="T_0c2be_row1_col0" class="data row1 col0" >Orthogonal Matching Pursuit</td>
#       <td id="T_0c2be_row1_col1" class="data row1 col1" >0.0881</td>
#       <td id="T_0c2be_row1_col2" class="data row1 col2" >0.0148</td>
#       <td id="T_0c2be_row1_col3" class="data row1 col3" >0.1213</td>
#       <td id="T_0c2be_row1_col4" class="data row1 col4" >0.9093</td>
#       <td id="T_0c2be_row1_col5" class="data row1 col5" >0.0094</td>
#       <td id="T_0c2be_row1_col6" class="data row1 col6" >0.0074</td>
#       <td id="T_0c2be_row1_col7" class="data row1 col7" >0.0140</td>
#     </tr>
#     <tr>
#       <th id="T_0c2be_level0_row2" class="row_heading level0 row2" >gbr</th>
#       <td id="T_0c2be_row2_col0" class="data row2 col0" >Gradient Boosting Regressor</td>
#       <td id="T_0c2be_row2_col1" class="data row2 col1" >0.0888</td>
#       <td id="T_0c2be_row2_col2" class="data row2 col2" >0.0156</td>
#       <td id="T_0c2be_row2_col3" class="data row2 col3" >0.1244</td>
#       <td id="T_0c2be_row2_col4" class="data row2 col4" >0.9037</td>
#       <td id="T_0c2be_row2_col5" class="data row2 col5" >0.0097</td>
#       <td id="T_0c2be_row2_col6" class="data row2 col6" >0.0074</td>
#       <td id="T_0c2be_row2_col7" class="data row2 col7" >0.0860</td>
#     </tr>
#     <tr>
#       <th id="T_0c2be_level0_row3" class="row_heading level0 row3" >ridge</th>
#       <td id="T_0c2be_row3_col0" class="data row3 col0" >Ridge Regression</td>
#       <td id="T_0c2be_row3_col1" class="data row3 col1" >0.0892</td>
#       <td id="T_0c2be_row3_col2" class="data row3 col2" >0.0166</td>
#       <td id="T_0c2be_row3_col3" class="data row3 col3" >0.1279</td>
#       <td id="T_0c2be_row3_col4" class="data row3 col4" >0.8977</td>
#       <td id="T_0c2be_row3_col5" class="data row3 col5" >0.0100</td>
#       <td id="T_0c2be_row3_col6" class="data row3 col6" >0.0075</td>
#       <td id="T_0c2be_row3_col7" class="data row3 col7" >0.0140</td>
#     </tr>
#     <tr>
#       <th id="T_0c2be_level0_row4" class="row_heading level0 row4" >lightgbm</th>
#       <td id="T_0c2be_row4_col0" class="data row4 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_0c2be_row4_col1" class="data row4 col1" >0.0910</td>
#       <td id="T_0c2be_row4_col2" class="data row4 col2" >0.0172</td>
#       <td id="T_0c2be_row4_col3" class="data row4 col3" >0.1302</td>
#       <td id="T_0c2be_row4_col4" class="data row4 col4" >0.8934</td>
#       <td id="T_0c2be_row4_col5" class="data row4 col5" >0.0102</td>
#       <td id="T_0c2be_row4_col6" class="data row4 col6" >0.0076</td>
#       <td id="T_0c2be_row4_col7" class="data row4 col7" >0.1590</td>
#     </tr>
#     <tr>
#       <th id="T_0c2be_level0_row5" class="row_heading level0 row5" >et</th>
#       <td id="T_0c2be_row5_col0" class="data row5 col0" >Extra Trees Regressor</td>
#       <td id="T_0c2be_row5_col1" class="data row5 col1" >0.0951</td>
#       <td id="T_0c2be_row5_col2" class="data row5 col2" >0.0188</td>
#       <td id="T_0c2be_row5_col3" class="data row5 col3" >0.1364</td>
#       <td id="T_0c2be_row5_col4" class="data row5 col4" >0.8839</td>
#       <td id="T_0c2be_row5_col5" class="data row5 col5" >0.0106</td>
#       <td id="T_0c2be_row5_col6" class="data row5 col6" >0.0080</td>
#       <td id="T_0c2be_row5_col7" class="data row5 col7" >0.1750</td>
#     </tr>
#     <tr>
#       <th id="T_0c2be_level0_row6"
# BayesianRidge()

# %% [markdown]
# br
# omp
# gbr
# ridge
# lightgbm
# et
# rf

# %% [markdown]
# ## Bagging Ensemble

# %%
models = {
    "gbr": GradientBoostingRegressor(verbose=0),
    "br": BayesianRidge(),
    "omp": OrthogonalMatchingPursuit(),
    "et": ExtraTreesRegressor(),
    "rf": RandomForestRegressor()
}

# %%
for name, model in models.items():
    model.fit(train_final, log_y)
    print(name + " trained.")
# Out:
# gbr trained.
# br trained.
# omp trained.
# et trained.
# rf trained.

# %% [markdown]
# ## Evaluate

# %%
results = {}

kf = KFold(n_splits = 10)

for name, model in models.items():
    result = np.exp(np.sqrt(- cross_val_score(model, train_final, log_y, scoring = 'neg_mean_squared_error', cv = kf)))
    results[name] = result

# %%
results
# Out:
# {'gbr': array([1.12841874, 1.10473032, 1.11904937, 1.1473761 , 1.15786149,
#         1.10804903, 1.13872306, 1.11726715, 1.10980109, 1.14666161]),
#  'br': array([1.12436258, 1.10824122, 1.12375813, 1.13539103, 1.15492506,
#         1.10307636, 1.13471608, 1.10474388, 1.10060412, 1.13475217]),
#  'omp': array([1.13098381, 1.11008719, 1.13000372, 1.13008093, 1.15787519,
#         1.1101573 , 1.12678807, 1.10815925, 1.10451802, 1.1478073 ]),
#  'et': array([1.13540617, 1.12174685, 1.1417994 , 1.14879697, 1.18837702,
#         1.10931617, 1.14023221, 1.12098472, 1.1242646 , 1.15100972]),
#  'rf': array([1.1556519 , 1.13038153, 1.14241387, 1.15133669, 1.17866509,
#         1.1138091 , 1.1543454 , 1.12560095, 1.1324369 , 1.16434483])}

# %%
for name, model in results.items():
    print(name)
    print(np.mean(result))
    print(np.std(result))
# Out:
# gbr
# 1.1448986257120486
# 0.018643565709715138
# br
# 1.1448986257120486
# 0.018643565709715138
# omp
# 1.1448986257120486
# 0.018643565709715138
# et
# 1.1448986257120486
# 0.018643565709715138
# rf
# 1.1448986257120486
# 0.018643565709715138

# %% [markdown]
# ## Combine Predictions

# %%
final_predictions = (
    0.2 * np.exp(models['gbr'].predict(test_final)) +
    0.2 * np.exp(models['br'].predict(test_final)) +
    0.2 * np.exp(models['omp'].predict(test_final)) +
    0.2 * np.exp(models['et'].predict(test_final)) +
    0.2 * np.exp(models['rf'].predict(test_final)) 
)

# %% [markdown]
# ## Submission

# %%
submission2 = pd.concat([test_ids, pd.Series(final_predictions, name = 'SalePrice')], axis = 1)

# %%
submission2.to_csv('./submission2.csv', index = False, header = True)

# %%
#01: 0.14094
#02: 0.13341
