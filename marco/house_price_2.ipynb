# %% [markdown]
# # House Prices Prediction

# %% [markdown]
# ### Import Libraries

# %%
#import tensorflow as tf
#import tensorflow_decision_forests as tfdf
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Read Data

# %%
training_set_path = '../dataset/train.csv'
training_set = pd.read_csv(training_set_path)

testing_set_path = '../dataset/test.csv'
testing_set = pd.read_csv(testing_set_path)

# %%
training_set.hist(column="SalePrice")
# Out:
# array([[<Axes: title={'center': 'SalePrice'}>]], dtype=object)

# %%
import numpy as np

#Transform the distribution to normal
training_set["SalePrice"] = np.log1p(training_set["SalePrice"])

# %%
training_set.hist(column="SalePrice")
# Out:
# array([[<Axes: title={'center': 'SalePrice'}>]], dtype=object)
